# %%
# !pip install pandas numpy

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df.head(n=3)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0

# %%
df.tail(n=3)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
#printing datatypes of csv file
df.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# Duration    False
# Date         True
# Pulse       False
# Maxpulse    False
# Calories    False
# dtype: bool

# %%
objectIndex = df.dtypes == 'int64'
objectIndex.dtypes
df.dtypes[objectIndex].index
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse'], dtype='object')

# %%
df[['Duration']][:5] #Slicing can be performed for printing rows
# Out:
#    Duration
# 0        60
# 1        60
# 2        60
# 3        45
# 4        45

# %%
df[['Duration', 'Pulse']].head() #For display of more than one column
# Out:
#    Duration  Pulse
# 0        60    110
# 1        60    117
# 2        60    103
# 3        45    109
# 4        45    117

# %%
df['newcol'] = 'Rohith'
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories  newcol
# 0         60  '2020/12/01'    110       130     409.1  Rohith
# 1         60  '2020/12/02'    117       145     479.0  Rohith
# 2         60  '2020/12/03'    103       135     340.0  Rohith
# 3         45  '2020/12/04'    109       175     282.4  Rohith
# 4         45  '2020/12/05'    117       148     406.0  Rohith
# 5         60  '2020/12/06'    102       127     300.0  Rohith
# 6         60  '2020/12/07'    110       136     374.0  Rohith
# 7        450  '2020/12/08'    104       134     253.3  Rohith
# 8         30  '2020/12/09'    109       133     195.1  Rohith
# 9         60  '2020/12/10'     98       124     269.0  Rohith
# 10        60  '2020/12/11'    103       147     329.3  Rohith
# 11        60  '2020/12/12'    100       120     250.7  Rohith
# 12        60  '2020/12/12'    100       120     250.7  Rohith
# 13        60  '2020/12/13'    106       128     345.3  Rohith
# ...

# %%
df.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  newcol
# 0      False  False  False     False     False   False
# 1      False  False  False     False     False   False
# 2      False  False  False     False     False   False
# 3      False  False  False     False     False   False
# 4      False  False  False     False     False   False
# 5      False  False  False     False     False   False
# 6      False  False  False     False     False   False
# 7      False  False  False     False     False   False
# 8      False  False  False     False     False   False
# 9      False  False  False     False     False   False
# 10     False  False  False     False     False   False
# 11     False  False  False     False     False   False
# 12     False  False  False     False     False   False
# 13     False  False  False     False     False   False
# 14     False  False  False     False     False   False
# 15     False  False  False     False     False   False
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories  newcol
# 18        45  '2020/12/18'     90       112       NaN  Rohith
# 22        45           NaN    100       119     282.0  Rohith
# 28        60  '2020/12/28'    103       132       NaN  Rohith

# %%
# df.fillna(120,inplace = True )
# df.dropna()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories  newcol
# 0         60  '2020/12/01'    110       130     409.1  Rohith
# 1         60  '2020/12/02'    117       145     479.0  Rohith
# 2         60  '2020/12/03'    103       135     340.0  Rohith
# 3         45  '2020/12/04'    109       175     282.4  Rohith
# 4         45  '2020/12/05'    117       148     406.0  Rohith
# 5         60  '2020/12/06'    102       127     300.0  Rohith
# 6         60  '2020/12/07'    110       136     374.0  Rohith
# 7        450  '2020/12/08'    104       134     253.3  Rohith
# 8         30  '2020/12/09'    109       133     195.1  Rohith
# 9         60  '2020/12/10'     98       124     269.0  Rohith
# 10        60  '2020/12/11'    103       147     329.3  Rohith
# 11        60  '2020/12/12'    100       120     250.7  Rohith
# 12        60  '2020/12/12'    100       120     250.7  Rohith
# 13        60  '2020/12/13'    106       128     345.3  Rohith
# ...

# %%
pd.Categorical(df['Duration'])
# Out:
# [60, 60, 60, 45, 45, ..., 60, 60, 60, 60, 60]
# Length: 32
# Categories (4, int64): [30, 45, 60, 450]

# %%
df['Pulse'].unique()
# Out:
# array([110, 117, 103, 109, 102, 104,  98, 100, 106,  90,  97, 108, 130,
#        105,  92])
