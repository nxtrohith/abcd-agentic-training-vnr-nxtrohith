# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from numpy.random import randn,randint, uniform, sample

# %%
iris = sn.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax = iris.plot(figsize=(15,8), title = 'iris Dataset Plot')
ax.set_xlabel("X-Axis")
ax.set_ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
d = pd.concat([iris.head(n = 4), iris.tail(n = 4)], ignore_index=True)
d
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    species
# 0           5.1          3.5           1.4          0.2     setosa
# 1           4.9          3.0           1.4          0.2     setosa
# 2           4.7          3.2           1.3          0.2     setosa
# 3           4.6          3.1           1.5          0.2     setosa
# 4           6.3          2.5           5.0          1.9  virginica
# 5           6.5          3.0           5.2          2.0  virginica
# 6           6.2          3.4           5.4          2.3  virginica
# 7           5.9          3.0           5.1          1.8  virginica

# %%
iris.loc[1:10].plot()
# Out:
# <Axes: >

# %%
iris.head(n=20).plot(kind = 'barh')
# Out:
# <Axes: >

# %%
iris.dropna().drop('species',axis=1).head(n=20).plot.hist(colormap = 'Set2')
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.scatter(x = "sepal_length", y = "petal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>
